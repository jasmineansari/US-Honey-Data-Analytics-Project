# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("US_honey_dataset.csv")

# %%
df.head()
# Out:
#    Unnamed: 0       state  colonies_number  yield_per_colony  production  \
# 0           0     Alabama            16000                58      928000
# 1           1     Arizona            52000                79     4108000
# 2           2    Arkansas            50000                60     3000000
# 3           3  California           420000                93    39060000
# 4           4    Colorado            45000                60     2700000
#
#     stocks  average_price  value_of_production  year
# 0    28000           62.0               575000  1995
# 1   986000           68.0              2793000  1995
# 2   900000           64.0              1920000  1995
# 3  4687000           60.0             23436000  1995
# 4  1404000           68.0              1836000  1995

# %%
#EDA
df=df.drop(['Unnamed: 0'],axis=1)

# %%
df
# Out:
#              state  colonies_number  yield_per_colony  production   stocks  \
# 0          Alabama            16000                58      928000    28000
# 1          Arizona            52000                79     4108000   986000
# 2         Arkansas            50000                60     3000000   900000
# 3       California           420000                93    39060000  4687000
# 4         Colorado            45000                60     2700000  1404000
# ...            ...              ...               ...         ...      ...
# 1110      Virginia             6000                40       79000    79000
# 1111    Washington            96000                32     1206000  1206000
# 1112  WestVirginia             6000                43      136000   136000
# 1113     Wisconsin            42000                47      750000   750000
# 1114       Wyoming            38000                58      242000   242000
#
#       average_price  value_of_production  year
# ...

# %%
df.head(10)
# Out:
#         state  colonies_number  yield_per_colony  production   stocks  \
# 0     Alabama            16000                58      928000    28000
# 1     Arizona            52000                79     4108000   986000
# 2    Arkansas            50000                60     3000000   900000
# 3  California           420000                93    39060000  4687000
# 4    Colorado            45000                60     2700000  1404000
# 5     Florida           230000                86    19780000  1780000
# 6     Georgia            70000                62     4340000   260000
# 7      Hawaii             8000               129     1032000   103000
# 8       Idaho           125000                48     6000000  1020000
# 9    Illinois            11000                74      814000   212000
#
#    average_price  value_of_production  year
# 0           62.0               575000  1995
# 1           68.0              2793000  1995
# 2           64.0              1920000  1995
# ...

# %%
df.tail(10)
# Out:
#              state  colonies_number  yield_per_colony  production   stocks  \
# 1105   SouthDakota           250000                49     5268000  5268000
# 1106     Tennessee             8000                56       81000    81000
# 1107         Texas           137000                56      384000   384000
# 1108          Utah            31000                33       92000    92000
# 1109       Vermont             7000                47       76000    76000
# 1110      Virginia             6000                40       79000    79000
# 1111    Washington            96000                32     1206000  1206000
# 1112  WestVirginia             6000                43      136000   136000
# 1113     Wisconsin            42000                47      750000   750000
# 1114       Wyoming            38000                58      242000   242000
#
#       average_price  value_of_production  year
# 1105           2.27             27808000  2021
# 1106           5.00              2240000  2021
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1115 entries, 0 to 1114
# Data columns (total 8 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   state                1115 non-null   object
#  1   colonies_number      1115 non-null   int64
#  2   yield_per_colony     1115 non-null   int64
#  3   production           1115 non-null   int64
#  4   stocks               1115 non-null   int64
#  5   average_price        1115 non-null   float64
#  6   value_of_production  1115 non-null   int64
#  7   year                 1115 non-null   int64
# dtypes: float64(1), int64(6), object(1)
# memory usage: 69.8+ KB

# %%
df.describe()
# Out:
#        colonies_number  yield_per_colony    production        stocks  \
# count      1115.000000       1115.000000  1.115000e+03  1.115000e+03
# mean      62438.565022         59.743498  2.851268e+06  1.172625e+06
# std       92648.175955         19.940500  5.561202e+06  2.049556e+06
# min        2000.000000         19.000000  1.200000e+04  9.000000e+03
# 25%        9000.000000         45.000000  2.460000e+05  1.125000e+05
# 50%       26000.000000         57.000000  8.280000e+05  3.700000e+05
# 75%       69000.000000         71.000000  2.700000e+06  1.253500e+06
# max      550000.000000        155.000000  3.906000e+07  1.354500e+07
#
#        average_price  value_of_production         year
# count    1115.000000         1.115000e+03  1115.000000
# mean      140.623076         5.667412e+06  2007.740807
# std       107.011544         9.459460e+06     7.823002
# min         1.300000         1.060000e+05  1995.000000
# 25%        70.000000         1.008000e+06  2001.000000
# ...

# %%
df["state"].unique()
# Out:
# array(['Alabama', 'Arizona', 'Arkansas', 'California', 'Colorado',
#        'Florida', 'Georgia', 'Hawaii', 'Idaho', 'Illinois', 'Indiana',
#        'Iowa', 'Kansas', 'Kentucky', 'Louisiana', 'Maine', 'Maryland',
#        'Michigan', 'Minnesota', 'Mississippi', 'Missouri', 'Montana',
#        'Nebraska', 'Nevada', 'NewJersey', 'NewMexico', 'NewYork',
#        'NorthCarolina', 'NorthDakota', 'Ohio', 'Oklahoma', 'Oregon',
#        'Pennsylvania', 'SouthCarolina', 'SouthDakota', 'Tennessee',
#        'Texas', 'Utah', 'Vermont', 'Virginia', 'Washington',
#        'WestVirginia', 'Wisconsin', 'Wyoming'], dtype=object)

# %%
df["state"].nunique()
# Out:
# 44

# %%
#Checking the null values
df.isnull().sum()
# Out:
# state                  0
# colonies_number        0
# yield_per_colony       0
# production             0
# stocks                 0
# average_price          0
# value_of_production    0
# year                   0
# dtype: int64

# %%
#Duplicate values checking
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1110    False
# 1111    False
# 1112    False
# 1113    False
# 1114    False
# Length: 1115, dtype: bool

# %%
df.duplicated().sum()
# Out:
# 0

# %%
#In case if any duplicates are there: df.drop_duplicates()

# %%
#Outlier analysis 
fig = plt.subplots(figsize=(20,10))
plt.subplot()
sns.boxplot(x=df['colonies_number'])
# Out:
# <AxesSubplot:xlabel='colonies_number'>

# %%
df.columns
# Out:
# Index(['state', 'colonies_number', 'yield_per_colony', 'production', 'stocks',
#        'average_price', 'value_of_production', 'year'],
#       dtype='object')

# %%
for col in df.columns:
    if df[col].dtype!="object":
        plt.boxplot(x=df[col])
        plt.xlabel(col)
        plt.show()

# %% [markdown]
# ## Analyzing the inferences from the data

# %% [markdown]
# Which states are contributing rarely for honey production since last 27 years

# %%
data=df["state"].value_counts()
data.values
# Out:
# array([27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27,
#        27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27,
#        27, 27, 27, 27, 26, 18, 15, 12,  9,  9], dtype=int64)

# %%
plt.figure(figsize=(13,13))
plt.pie(data.values,labels=data.index,autopct="%0.2f%%")
plt.show()

# %%
#Inference:
#Top 5 states contributing less in last 27 years are:
#  NewMexico        18
#  Nevada           15
#  SouthCarolina    12
#  Oklahoma          9
#  Maryland          9

# %%
print(data)
# Out:
# Alabama          27
# Missouri         27
# Arizona          27
# NewJersey        27
# NewYork          27
# NorthCarolina    27
# NorthDakota      27
# Ohio             27
# Oregon           27
# Pennsylvania     27
# SouthDakota      27
# Tennessee        27
# Texas            27
# Utah             27
# Vermont          27
# Virginia         27
# Washington       27
# WestVirginia     27
# Wisconsin        27
# Montana          27
# Nebraska         27
# Mississippi      27
# Minnesota        27
# Arkansas         27
# California       27
# Colorado         27
# Florida          27
# Georgia          27
# Hawaii           27
# Idaho            27
# Illinois         27
# Indiana          27
# Iowa             27
# Kansas           27
# Louisiana        27
# Maine            27
# Michigan         27
# Wyoming          27
# Kentucky         26
# NewMexico        18
# Nevada           15
# SouthCarolina    12
# Oklahoma          9
# Maryland          9
# Name: state, dtype: int64

# %% [markdown]
# ### Which are the top 5 Honey producing states?

# %%
plt.figure(figsize=(15,10))
sns.barplot(x=df["state"],y=df["production"],ci=None)
plt.xticks(rotation=90)
plt.show()

# %%
new_df=df.groupby("state").sum().reset_index()

# %%
new_df=new_df.sort_values("production",ascending=False)

# %%
new_df
# Out:
#             state  colonies_number  yield_per_colony  production     stocks  \
# 28    NorthDakota         10710000              2266   513742000  206707000
# 3      California         10135000              1426   423876000  137611000
# 34    SouthDakota          6639000              1950   355726000  218634000
# 5         Florida          5528000              1956   280934000   47037000
# 21        Montana          3725000              2148   197173000   91240000
# 18      Minnesota          3498000              1885   176581000   51908000
# 36          Texas          2876000              1921   129441000   41022000
# 17       Michigan          2168000              1753   101063000   58401000
# 42      Wisconsin          1698000              1896    99909000   59166000
# 8           Idaho          2705000              1121    87188000   40503000
# 26        NewYork          1588000              1745    78444000   42535000
# ...

# %%
plt.figure(figsize=(15,10))
sns.barplot(x=new_df["state"],y=new_df["production"],ci=None)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ### Change in mean Average price of Honey from 1995 to 2021

# %%
df1=df.groupby("year").mean()['average_price'].reset_index()

# %%
df1
# Out:
#     year  average_price
# 0   1995      74.840909
# 1   1996      99.568182
# 2   1997      91.325581
# 3   1998      83.720930
# 4   1999      80.325581
# 5   2000      79.023256
# 6   2001      88.465116
# 7   2002     133.204545
# 8   2003     151.068182
# 9   2004     132.350000
# 10  2005     116.341463
# 11  2006     134.341463
# 12  2007     140.170732
# 13  2008     160.878049
# 14  2009     176.195122
# 15  2010     192.900000
# 16  2011     216.725000
# 17  2012     236.700000
# 18  2013     260.717949
# 19  2014     282.025000
# 20  2015     292.625000
# 21  2016     291.925000
# 22  2017     302.775000
# 23  2018       3.083500
# 24  2019       2.925500
# 25  2020       3.050000
# 26  2021       3.334250

# %%
plt.figure(figsize=(15,10))
sns.barplot(x=df1["year"],y=df1["average_price"],ci=None)
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(15,10))
plt.plot(df1["year"], df1["average_price"])
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ### Which was the year when production of Honey in the whole US was the highest?

# %%
df2=df.groupby("year").sum()["production"].reset_index()

# %%
df2
# Out:
#     year  production
# 0   1995   210272000
# 1   1996   197995000
# 2   1997   191176000
# 3   1998   219321000
# 4   1999   204585000
# 5   2000   220320000
# 6   2001   185403000
# 7   2002   170732000
# 8   2003   180741000
# 9   2004   182379000
# 10  2005   173857000
# 11  2006   154120000
# 12  2007   147609000
# 13  2008   160096000
# 14  2009   143340000
# 15  2010    44797000
# 16  2011    36550000
# 17  2012    31662000
# 18  2013    37974000
# 19  2014    40990000
# 20  2015    41832000
# 21  2016    40837000
# 22  2017    30478000
# 23  2018    28989000
# 24  2019    40510000
# 25  2020    39412000
# 26  2021    23187000

# %%
#Trend of honey productions
plt.figure(figsize=(15,10))
plt.plot(df2["year"], df2["production"])
plt.xticks(rotation=90)
plt.show()

# %%
df2=df2.sort_values("production",ascending=False)

# %%
plt.figure(figsize=(15,10))
sns.barplot(x=df2["year"],y=df2["production"],ci=None)
plt.xticks(rotation=90)
plt.show()

# %%
df2['production'].idxmax()
# Out:
# 5

# %%
df2['production'].max()
# Out:
# 220320000

# %%
df3=df[df['year']==2000]

# %%
df3
# Out:
#              state  colonies_number  yield_per_colony  production    stocks  \
# 217        Alabama            16000                78     1248000    187000
# 218        Arizona            40000                59     2360000   1322000
# 219       Arkansas            55000                93     5115000   3529000
# 220     California           440000                70    30800000  11396000
# 221       Colorado            29000                60     1740000    957000
# 222        Florida           232000               105    24360000   2923000
# 223        Georgia            55000                57     3135000    376000
# 224         Hawaii             7000               112      784000    125000
# 225          Idaho           100000                47     4700000   2679000
# 226       Illinois             8000                61      488000    146000
# 227        Indiana             8000                65      520000    286000
# ...

# %%
plt.figure(figsize=(15,10))
sns.barplot(x=df3["state"],y=df3["production"],ci=None)
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(15,15))
plt.pie(df3['production'],labels=df3['state'],autopct="%0.2f%%")
plt.show()

# %% [markdown]
# ### Which states are having the highest no. of colonies in year 2000?

# %%
plt.figure(figsize=(15,10))
sns.barplot(x=df3["state"],y=df3["colonies_number"],ci=None)
plt.xticks(rotation=90)
plt.show()

# %%
# inference: even the no. of colonies are highest in California,still production of honey is highest for North dakota.

# %%
#Final inferences:
    # inference 1: top 5 states contributing less in last 27 years are:
#         Maryland          9
         #Oklahoma          9
#         SouthCarolina    12
#         Nevada           15
#         NewMexico        18
    
    # inference 2:
# Top 5 Honey Producing states are:
#     North Dakota
#     california
#     south dakota
#     florida
#     montana

# inference 3:
#     from the 1995 to 2017 we can see an increasing trend in the avg price of honey but after 2017 the avg price
#     falls sudenly and remains constant till 2021

# inference 4: production of honey decreasing drastically

# inference 5: In year 2000 the production of Honey was highest.

#inderence 6:
# in 2000 the north dakota was having highest contribution towards the production

# inference7: even the no. of colonies are highest in California,still production of honey is highest for North dakota.
